# %%
import praw
import csv
import time  # import the time module

reddit = praw.Reddit(
    client_id='qxBgcwES4X6f1pjmDkvNlQ',
    client_secret='xK42np66vumZbfTHb79pljxTrhPOBg',
    user_agent='adviceA'
)

subreddit = reddit.subreddit('cscareerquestions')

posts = {}
for post in subreddit.new(limit=500):
    post.comments.replace_more(limit=None)
    top_comments = []
    for comment in post.comments.list()[:20]:
        top_comments.append(comment.body)
    posts[post.title] = top_comments
    time.sleep(2)  # sleep for 2 seconds

# Write data to CSV file
with open('reddit_posts.csv', 'w', newline='', encoding='utf-8') as f:
    writer = csv.writer(f)
    writer.writerow(['Title', 'Top Comments'])
    for title, comments in posts.items():
        writer.writerow([title, '; '.join(comments)])
# Out:
# WARNING:praw:It appears that you are using PRAW in an asynchronous environment.
# It is strongly recommended to use Async PRAW: https://asyncpraw.readthedocs.io.
# See https://praw.readthedocs.io/en/latest/getting_started/multiple_instances.html#discord-bots-and-asynchronous-environments for more info.
#
# WARNING:praw:It appears that you are using PRAW in an asynchronous environment.
# It is strongly recommended to use Async PRAW: https://asyncpraw.readthedocs.io.
# See https://praw.readthedocs.io/en/latest/getting_started/multiple_instances.html#discord-bots-and-asynchronous-environments for more info.
#
# WARNING:praw:It appears that you are using PRAW in an asynchronous environment.
# It is strongly recommended to use Async PRAW: https://asyncpraw.readthedocs.io.
# See https://praw.readthedocs.io/en/latest/getting_started/multiple_instances.html#discord-bots-and-asynchronous-environments for more info.
#
# ...

# %%
# !pip install praw
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 191.0/191.0 kB 3.8 MB/s eta 0:00:00
# ...

# %%
pip install -qU langchain-google-vertexai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 1.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.6/125.6 kB 8.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.9/307.9 kB 19.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.0/139.0 kB 12.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.2/121.2 kB 12.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 3.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.5/142.5 kB 12.5 MB/s eta 0:00:00

# %%
import os

# Set the path of the service account file
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "/content/service_account.json"

from langchain_google_vertexai import ChatVertexAI

llm = ChatVertexAI(model="gemini-pro")

# %%
pip install pandas langchain langchain-chroma langchain-community langchain-core langchain-openai langchain-text-splitters langchain-google-vertexai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 973.7/973.7 kB 6.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 15.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 526.8/526.8 kB 25.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 11.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.6/320.6 kB 26.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 29.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 36.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 7.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 4.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 43.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.1/60.1 kB 7.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.1/106.1 kB 9.2 MB/s eta 0:00:00
# ...

# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import FAISS
from langchain.chat_models import ChatOpenAI
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain_core.prompts import ChatPromptTemplate
from langchain.chains import create_retrieval_chain

# %%
import json
import langchain_core

# Load JSON data
with open('reddit_posts.json', 'r') as file:
    json_data = json.load(file)

# Initialize the RecursiveTextSplitter
splitter = RecursiveCharacterTextSplitter(chunk_size=512, chunk_overlap=50)

# Prepare the data for splitting
documents = []
for entry in json_data:
    question = entry['Title']
    answers = entry['Top Comments']

    # Combine the question and answers into a single text block
    combined_text = answers

    # Split the combined text into chunks
    chunks = splitter.split_text(combined_text)

    # Create a document for each chunk
    for chunk in chunks:
        lcc_d = langchain_core.documents.base.Document(page_content=chunk, metadata={"question": question})
        documents.append(lcc_d)

# %%
import json
import langchain_core

# Load JSON data
with open('reddit_posts.json', 'r') as file:
    json_data = json.load(file)

# Initialize the RecursiveTextSplitter
splitter = RecursiveCharacterTextSplitter(chunk_size=512, chunk_overlap=50)

# Prepare the data for splitting
documents = []
for entry in json_data:
    question = entry['Title']
    answers = entry['Top Comments']

    # Combine the question and answers into a single text block
    combined_text = answers

    # Split the combined text into chunks
    chunks = splitter.split_text(combined_text)

    # Create a document for each chunk
    for chunk in chunks:
        lcc_d = langchain_core.documents.base.Document(page_content=chunk, metadata={"question": question})
        documents.append(lcc_d)

# %%
from langchain_chroma import Chroma
from langchain_openai import OpenAIEmbeddings
from dotenv import load_dotenv

# %%
import os

vectorstore = Chroma.from_documents(documents=documents, persist_directory="./chromadb", embedding=OpenAIEmbeddings(openai_api_key="sk-proj-IOzFRrBYg586gxZgtNjRT3BlbkFJa4XWFpR9d6gdGrmV9AJS"))

# %%
embedding = OpenAIEmbeddings(openai_api_key="sk-proj-Rt4nPBd26POdsxcuQii3T3BlbkFJXzRxz0r9rL2PhuJDm3MI")
db = Chroma(persist_directory="./chromadb",embedding_function=embedding)

# %%
# Create retriever
retriever = db.as_retriever()

# Define prompt template
template = """
You are an assistant for question-answering tasks.
Use the provided context to help you answer the following question:

<context>
{context}
</context>

Question: {input}
"""

# Create a prompt template
prompt = ChatPromptTemplate.from_template(template)

# Create a chain
doc_chain = create_stuff_documents_chain(llm, prompt)
chain = create_retrieval_chain(retriever, doc_chain)

# %%
# User query
response = chain.invoke({"input": "Do CS jobs lead to burnout"})

# Do CS jobs lead to burnout
# Backend development roadmap, with a Python focus
# Internship preparation
#How's the current CS Job market

# Get the Answer only
response['answer']
# Out:
# "## Do CS jobs lead to burnout? \n\nBased on the provided context, it seems CS jobs **can** lead to burnout, but it's not inevitable. Here are some key points to consider:\n\n**Factors contributing to burnout:**\n\n* **High stress and lack of energy:**  The context mentions that the author's initial burnout wasn't caused by the technical aspects of the job, but rather the stress and lack of energy. This suggests that demanding work environments and long hours can play a significant role in burnout.\n* **Burnout is often self-induced:** The author emphasizes that burnout is often self-inflicted, implying that individuals have some control over their mental and physical well-being. \n* **Nature of the job:** The context acknowledges that the nature of being a software engineer can be demanding, requiring long hours and repetitive tasks. This might not be suitable for everyone, and some individuals might be more prone to burnout than others.\n* **Short-term jobs:** The context highlight
# ...

# %%
# from fastapi import FastAPI

# from fastapi.middleware.cors import CORSMiddleware

# import nest_asyncio
# import uvicorn

# app = FastAPI()

# origins = [
#     "http://localhost",
#     "http://localhost:5173",
# ]

# app.add_middleware(
#     CORSMiddleware,
#     allow_origins=origins,
#     allow_credentials=True,
#     allow_methods=["*"],
#     allow_headers=["*"],
# )

# @app.get("/q/")
# async def read_q(question: str = ""):
#     # User query
#     response = chain.invoke({"input": question})

# # Get the Answer only
#     response['answer']
#     print(response)
#     return {"question": response}

# @app.get("/sub/")
# async def read_s(subreddit: str = "cscareeradvice"):
#     return {"subreddit": subreddit}



# if __name__ == "__main__":
#     nest_asyncio.apply()
#     uvicorn.run(app)
